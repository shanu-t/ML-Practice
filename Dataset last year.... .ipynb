# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\dell\Downloads\archive (4)\TSLA Testing.csv")

# %%
df.head(4)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-06-22  234.503326  246.833328  233.826660  236.086670  236.086670
# 1  2022-06-23  237.906662  239.316666  228.636673  235.070007  235.070007
# 2  2022-06-24  237.470001  246.066666  236.086670  245.706665  245.706665
# 3  2022-06-27  249.366669  252.070007  242.566666  244.919998  244.919998
#
#       Volume
# 0  101107500
# 1  104202600
# 2   95770800
# 3   89178300

# %%
df.shape
# Out:
# (251, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       251 non-null    object
#  1   Open       251 non-null    float64
#  2   High       251 non-null    float64
#  3   Low        251 non-null    float64
#  4   Close      251 non-null    float64
#  5   Adj Close  251 non-null    float64
#  6   Volume     251 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
df2 = pd.read_csv(r"C:\Users\dell\Downloads\archive (4)\TSLA training.csv")

# %%
df2
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2018-06-22   23.436001   23.483334   22.133333   22.242001   22.242001
# 1     2018-06-25   22.007999   22.564667   21.833332   22.200666   22.200666
# 2     2018-06-26   22.403334   22.903334   21.719999   22.799999   22.799999
# 3     2018-06-27   23.000000   23.386000   22.633333   22.966667   22.966667
# 4     2018-06-28   23.243999   23.801332   23.073999   23.328667   23.328667
# ...          ...         ...         ...         ...         ...         ...
# 1252  2023-06-14  260.170013  261.570007  250.500000  256.790009  256.790009
# 1253  2023-06-15  248.399994  258.950012  247.289993  255.899994  255.899994
# 1254  2023-06-16  258.920013  263.600006  257.209991  260.540009  260.540009
# 1255  2023-06-20  261.500000  274.750000  261.119995  274.450012  274.450012
# 1256  2023-06-21  275.130005  276.989990  257.779999  259.459991  259.459991
#
#          Volume
# 0     153991500
# ...

# %%
df2.head(4)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2018-06-22  23.436001  23.483334  22.133333  22.242001  22.242001
# 1  2018-06-25  22.007999  22.564667  21.833332  22.200666  22.200666
# 2  2018-06-26  22.403334  22.903334  21.719999  22.799999  22.799999
# 3  2018-06-27  23.000000  23.386000  22.633333  22.966667  22.966667
#
#       Volume
# 0  153991500
# 1  103969500
# 2  111787500
# 3  125005500

# %%
pd.concat([df,df2])
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2022-06-22  234.503326  246.833328  233.826660  236.086670  236.086670
# 1     2022-06-23  237.906662  239.316666  228.636673  235.070007  235.070007
# 2     2022-06-24  237.470001  246.066666  236.086670  245.706665  245.706665
# 3     2022-06-27  249.366669  252.070007  242.566666  244.919998  244.919998
# 4     2022-06-28  244.483337  249.970001  232.343338  232.663330  232.663330
# ...          ...         ...         ...         ...         ...         ...
# 1252  2023-06-14  260.170013  261.570007  250.500000  256.790009  256.790009
# 1253  2023-06-15  248.399994  258.950012  247.289993  255.899994  255.899994
# 1254  2023-06-16  258.920013  263.600006  257.209991  260.540009  260.540009
# 1255  2023-06-20  261.500000  274.750000  261.119995  274.450012  274.450012
# 1256  2023-06-21  275.130005  276.989990  257.779999  259.459991  259.459991
#
#          Volume
# 0     101107500
# ...

# %%
df.head(4)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-06-22  234.503326  246.833328  233.826660  236.086670  236.086670
# 1  2022-06-23  237.906662  239.316666  228.636673  235.070007  235.070007
# 2  2022-06-24  237.470001  246.066666  236.086670  245.706665  245.706665
# 3  2022-06-27  249.366669  252.070007  242.566666  244.919998  244.919998
#
#       Volume
# 0  101107500
# 1  104202600
# 2   95770800
# 3   89178300

# %%
def calStatus(value):
    if(value>0):
        return 1
    else:
        return 0

# %%
df['Profit_status'] = (df['Close']-df['Open']).map(calStatus)

# %%
df.head(3)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2022-06-22  234.503326  246.833328  233.826660  236.086670  236.086670
# 1  2022-06-23  237.906662  239.316666  228.636673  235.070007  235.070007
# 2  2022-06-24  237.470001  246.066666  236.086670  245.706665  245.706665
#
#       Volume  Profit_status
# 0  101107500              1
# 1  104202600              0
# 2   95770800              1

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=["Date","Profit_status"]),df["Profit_status"],random_state=11,test_size=0.2)

# %%
X_train.head()
# Out:
#            Open        High         Low       Close   Adj Close     Volume
# 102  195.880005  200.820007  192.059998  194.419998  194.419998   91293800
# 16   240.000000  243.623337  236.889999  240.066666  240.066666   69683100
# 103  191.509995  192.570007  185.660004  186.919998  186.919998   66567600
# 197  197.320007  198.740005  190.320007  192.580002  192.580002  126463800
# 0    234.503326  246.833328  233.826660  236.086670  236.086670  101107500

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale = MinMaxScaler(feature_range=(0,1))

# %%
scale.set_output(transform="pandas")
# Out:
# MinMaxScaler()

# %%
X_train = scale.fit_transform(X_train)

# %%
X_test = scale.fit_transform(X_test)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfc.score(X_test,y_test)
# Out:
# 0.7254901960784313

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred = rfc.predict(X_test)
cm = confusion_matrix(y_pred,y_test)

# %%
cm
# Out:
# array([[ 8,  4],
#        [10, 29]])

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(X_test,y_test)
# Out:
# 0.6666666666666666
