# %%
import pandas as pd 
ds =pd.read_excel(r"C:\Users\dell\Downloads\OrdersDtaa.xlsx")
ds.isnull().sum()/ds.shape[0]*100
ds.shape
# Out:
# (1952, 8)

# %%
import pandas as pd 
ds =pd.read_excel(r"C:\Users\dell\Downloads\P6-SuperStoreUS-2015.xlsx")
ds.isnull().sum()/ds.shape[0]*100
# Out:
# Row ID                    0.000000
# Order Priority            0.000000
# Discount                  0.000000
# Unit Price                0.000000
# Shipping Cost             0.000000
# NetUnitPrice              0.000000
# Customer ID               0.000000
# Customer Name             0.000000
# Ship Mode                 0.000000
# Customer Segment          0.000000
# Product Category          0.000000
# Product Sub-Category      0.000000
# Product Container         0.000000
# Product Name              0.000000
# Product Base Margin       0.819672
# SellUnitPrice             0.000000
# Country                   0.000000
# Region                    0.000000
# State or Province         0.000000
# City                      0.000000
# Postal Code               0.000000
# Order Date                0.000000
# Ship Date                 0.000000
# Profit                    0.000000
# Quantity ordered new      0.000000
# Sales                     0.000000
# Order ID                  0.000000
# ...

# %%
import pandas as pd 
ds =pd.read_excel(r"C:\Users\dell\Downloads\P6-SuperStoreUS-2015.xlsx")
ds.isnull().sum().sum()/(ds.shape[0]*ds.shape[1])*100
ds.shape

ds.fillna("XY")
ds.head(20)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  NetUnitPrice  \
# 0    20847           High      0.01        2.84           0.93        3.7416
# 1    20228  Not Specified      0.02      500.98          26.00      516.9604
# 2    21776       Critical      0.06        9.48           7.29       16.2012
# 3    24844         Medium      0.09       78.69          19.99       91.5979
# 4    24846         Medium      0.08        3.28           2.31        5.3276
# 5    24847         Medium      0.05        3.28           4.20        7.3160
# 6    24848         Medium      0.05        3.58           1.63        5.0310
# 7    18181       Critical      0.00        4.42           4.99        9.4100
# 8    20925         Medium      0.01       35.94           6.66       42.2406
# 9    26267           High      0.04        2.98           1.58        4.4408
# 10   26268           High      0.05      115.99           2.50      112.6905
# ...

# %%
import pandas as pd 
ds =pd.read_excel(r"C:\Users\dell\Downloads\P6-SuperStoreUS-2015.xlsx")
ds.isnull().sum().sum()/(ds.shape[0]*ds.shape[1])*100

ds.fillna(method="ffill",axis=1).head(20)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3992\3995899702.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ds.fillna(method="ffill",axis=1).head(20)
#    Row ID Order Priority Discount Unit Price Shipping Cost NetUnitPrice  \
# 0   20847           High     0.01       2.84          0.93       3.7416
# 1   20228  Not Specified     0.02     500.98          26.0     516.9604
# 2   21776       Critical     0.06       9.48          7.29      16.2012
# 3   24844         Medium     0.09      78.69         19.99      91.5979
# 4   24846         Medium     0.08       3.28          2.31       5.3276
# 5   24847         Medium     0.05       3.28           4.2        7.316
# 6   24848         Medium     0.05       3.58          1.63        5.031
# 7   18181       Critical      0.0       4.42          4.99         9.41
# 8   20925         Medium     0.01      35.94          6.66      42.2406
# ...

# %%
import pandas as pd 
ds =pd.read_excel(r"C:\Users\dell\Downloads\P6-SuperStoreUS-2015.xlsx")
ds.isnull().sum().sum()/(ds.shape[0]*ds.shape[1])*100

ds["Order Priority"].fillna(method="ffill").head(20)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_3992\344670593.py:5: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   ds["Order Priority"].fillna(method="ffill").head(20)
# 0              High
# 1     Not Specified
# 2          Critical
# 3            Medium
# 4            Medium
# 5            Medium
# 6            Medium
# 7          Critical
# 8            Medium
# 9              High
# 10             High
# 11             High
# 12    Not Specified
# 13             High
# 14    Not Specified
# 15    Not Specified
# 16             High
# 17             High
# 18    Not Specified
# 19             High
# Name: Order Priority, dtype: object

# %%
import pandas as pd 
ds =pd.read_excel(r"C:\Users\dell\Downloads\P6-SuperStoreUS-2015.xlsx")
ds["Order Priority"].mode()[0]
ds["Order Priority"].fillna(ds["Order Priority"].mode()[0])
ds.select_dtypes(include="object").columns
# Out:
# Index(['Order Priority', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Country', 'Region', 'State or Province', 'City',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 35'],
#       dtype='object')

# %%
import pandas as pd 
ds =pd.read_excel(r"C:\Users\dell\Downloads\P6-SuperStoreUS-2015.xlsx")
for a in ds.select_dtypes(include="object").columns:
    ds[a]=ds[a].fillna(ds[a].mode()[0])
for a in ds.select_dtypes(include="int64").columns:
    ds[a]=ds[a].fillna(ds[a].mean())
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_4308\2016488187.py:4: UserWarning: Unable to sort modes: '<' not supported between instances of 'int' and 'str'
#   ds[a]=ds[a].fillna(ds[a].mode()[0])
# C:\Users\dell\AppData\Local\Temp\ipykernel_4308\2016488187.py:4: UserWarning: Unable to sort modes: '<' not supported between instances of 'float' and 'str'
#   ds[a]=ds[a].fillna(ds[a].mode()[0])
