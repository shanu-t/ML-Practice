# %%
import pandas as pd 
df = pd .read_csv(r"C:\Users\dell\Downloads\used_car_dataset.csv")
df
# Out:
#               Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000 km       Manual  second
# 1            Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
# ...             ...        ...   ...  ...          ...          ...     ...
# 9577          Skoda    Octavia  2014   10   105,904 km    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km       Manual   first
# 9580        Hyundai      Verna  2019    5    72,000 km    Automatic   first
# 9581        Hyundai    New i20  2021    3    83,228 km       Manual  second
#
#         FuelType PostedDate  \
# ...

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\dell\Downloads\OrdersDtaa.xlsx")
df
# Out:
#       Order ID  CustomerID   Amount     Profit  Quantity ordered new  \
# 0        88522        4666    11.36     4.5600                     4
# 1        90193        4663  6011.76  4390.3665                    12
# 2        90192        2583   208.56   -53.8096                    22
# 3        86838        8372  1259.04   803.4705                    16
# 4        86838        6458    22.96   -24.0300                     7
# ...        ...         ...      ...        ...                   ...
# 1947     87536        2357   196.20  -116.7600                    18
# 1948     87536        7876   175.78  -160.9520                    22
# 1949     87534        5265    59.85   -41.8700                     5
# 1950     87537        1573   140.70   -24.7104                    15
# 1951     87530        4666   529.90   349.4850                     5
#
#      Product Category          Product Sub-Category Payment Mode
# 0     Office Supplies           Pens & Art Supplies  Credit Card
# ...

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\dell\Downloads\OrdersDtaa.xlsx")
df.shape
# Out:
# (1952, 8)

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\dell\Downloads\OrdersDtaa.xlsx")
df.isnull().sum()
# Out:
# Order ID                0
# CustomerID              0
# Amount                  0
# Profit                  1
# Quantity ordered new    0
# Product Category        1
# Product Sub-Category    1
# Payment Mode            0
# dtype: int64

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\dell\Downloads\OrdersDtaa.xlsx")
df.isnull().sum().sum()
# Out:
# 3

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\dell\Downloads\OrdersDtaa.xlsx")
df.shape[0]*df.shape[1]
# Out:
# 15616

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\dell\Downloads\OrdersDtaa.xlsx")
df.isnull().sum()
# Out:
# Order ID                0
# CustomerID              0
# Amount                  0
# Profit                  1
# Quantity ordered new    0
# Product Category        1
# Product Sub-Category    1
# Payment Mode            0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Order ID                0
# CustomerID              0
# Amount                  0
# Profit                  1
# Quantity ordered new    0
# Product Category        1
# Product Sub-Category    1
# Payment Mode            0
# dtype: int64

# %%
100-(((df.isnull().sum().sum())/(df.shape[0]*df.shape[1]))*100)
# Out:
# 99.98078893442623

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\dell\Downloads\OrdersDtaa.xlsx")
df=df.dropna()
df["NetProfit"]=df["Profit"]*df["Quantity ordered new"]
df = df.drop("Payment Mode",axis="columns")
df.head()
# Out:
#    Order ID  CustomerID   Amount     Profit  Quantity ordered new  \
# 0     88522        4666    11.36     4.5600                     4
# 1     90193        4663  6011.76  4390.3665                    12
# 2     90192        2583   208.56   -53.8096                    22
# 3     86838        8372  1259.04   803.4705                    16
# 4     86838        6458    22.96   -24.0300                     7
#
#   Product Category Product Sub-Category   NetProfit
# 0  Office Supplies  Pens & Art Supplies     18.2400
# 1        Furniture   Chairs & Chairmats  52684.3980
# 2        Furniture   Office Furnishings  -1183.8112
# 3        Furniture   Office Furnishings  12855.5280
# 4  Office Supplies  Pens & Art Supplies   -168.2100

# %%
import pandas as pd
df = pd.read_excel(r"C:\Users\dell\Downloads\OrdersDtaa.xlsx")
df=df.dropna()
df["NetProfit"]=df["Profit"]*df["Quantity ordered new"]
df = df.drop("Payment Mode",axis="columns")


def substr(value):
    return value.split()[0]
    
print(df["Product Sub-Category"][0].split()[0])
df.head(10)
# Out:
# Pens
#     Order ID  CustomerID   Amount     Profit  Quantity ordered new  \
# 0      88522        4666    11.36     4.5600                     4
# 1      90193        4663  6011.76  4390.3665                    12
# 2      90192        2583   208.56   -53.8096                    22
# 3      86838        8372  1259.04   803.4705                    16
# 4      86838        6458    22.96   -24.0300                     7
# 6      86838        8264    14.32    -0.7100                     4
# 9      86836        5243    17.88     2.6300                     6
# 10     86836        5654  1159.90   652.7331                    10
# 11     90031        2357   450.16   314.4813                    17
# 12     90032        7876   233.82  -114.6399                    18
#
#    Product Category          Product Sub-Category   NetProfit
# 0   Office Supplies           Pens & Art Supplies     18.2400
# 1         Furniture            Chairs & Chairmats  52684.3980
# ...
